# %% [markdown]
# # Lektion 2026-02-20

# %%
A = {1,2,3}
B = {2,3,4}

# Vereinungsmenge von A & B
res1 = A | B

# Schnittmenge von A & B
res2 = A & B

# Differenz von A & B
res3 = A - B

# Symmetrische Differenz
res4 = A ^ B

print(f"{res1=}, {res2=}, {res3=}, {res4=}")
# Out:
# res1={1, 2, 3, 4}, res2={2, 3}, res3={1}, res4={1, 4}
